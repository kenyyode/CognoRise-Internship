# %% [markdown]
# ### Project Introduction
#
# #### About this Dataset
#
# Fields in the dataset:
#
# Name: Name of cereal
# mfr: Manufacturer of cereal
# A = American Home Food Products;
# G = General Mills
# K = Kelloggs
# N = Nabisco
# P = Post
# Q = Quaker Oats
# R = Ralston Purina
# type:
# cold
# hot
# calories: calories per serving
# protein: grams of protein
# fat: grams of fat
# sodium: milligrams of sodium
# fiber: grams of dietary fiber
# carbo: grams of complex carbohydrates
# sugars: grams of sugars
# potass: milligrams of potassium
# vitamins: vitamins and minerals - 0, 25, or 100, indicating the typical percentage of FDA recommended
# shelf: display shelf (1, 2, or 3, counting from the floor)
# weight: weight in ounces of one serving
# cups: number of cups in one serving
# rating: a rating of the cereals (Possibly from Consumer Reports?)

# %% [markdown]
# ## 80 Cereals
# Nutrition data on 80 cereal product

# %% [markdown]
# #### Project Objectives

# %% [markdown]
# 1. to assess Nutritional characteristics of popular cereal
# 2. to compare differences in Nutritional values between cereals from different companies
# 3. to assess the relationships between interdependent nutritonal constituents.

# %%
import opendatasets as od 

od.download("https://www.kaggle.com/datasets/crawford/80-cereals?resource=download")
# Out:
# Skipping, found downloaded files in ".\80-cereals" (use force=True to force download)

# %% [markdown]
# ### Loading the dataset

# %%
import pandas as pd 
import seaborn as sns 
import numpy as np 
import matplotlib as mpl 
import matplotlib.pyplot as plt 

# %matplotlib inline

mpl.style.use("ggplot")

# %%
df = pd.read_csv("80-cereals/cereal.csv")

# %% [markdown]
# ### Exploring the dataset

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df.columns = df.columns.str.capitalize()

# %%
## renaming selected columns from clarity
df.rename(columns={
    'Mfr':'Manufacturer',
    'Potass':'Pottasium(mg)',
    'Fat':'Fat(g)'}, inplace=True)

# %%
## let us take a look at the dataset
df.head()
# Out:
#                         Name Manufacturer Type  Calories  Protein  Fat(g)  \
# 0                  100% Bran            N    C        70        4       1
# 1          100% Natural Bran            Q    C       120        3       5
# 2                   All-Bran            K    C        70        4       1
# 3  All-Bran with Extra Fiber            K    C        50        4       0
# 4             Almond Delight            R    C       110        2       2
#
#    Sodium  Fiber  Carbo  Sugars  Pottasium(mg)  Vitamins  Shelf  Weight  Cups  \
# 0     130   10.0    5.0       6            280        25      3     1.0  0.33
# 1      15    2.0    8.0       8            135         0      3     1.0  1.00
# 2     260    9.0    7.0       5            320        25      3     1.0  0.33
# 3     140   14.0    8.0       0            330        25      3     1.0  0.50
# 4     200    1.0   14.0       8             -1        25      3     1.0  0.75
#
#       Rating
# 0  68.402973
# 1  33.983679
# 2  59.425505
# 3  93.704912
# 4  34.384843

# %% [markdown]
# We need to assign manufacturer names to the make the data easier to interprete

# %%
name_dict = {'A' : 'American Home Food Products',
            'G' : 'General Mills',
            'K' : 'Kelloggs',
            'N' : 'Nabisco',
            'P' : 'Post',
            'Q' : 'Quaker Oats',
            'R' : 'Ralston Purina'}

df['Manufacturer']= df['Manufacturer'].map(name_dict)

# %% [markdown]
# Same thing for the Type of cereal

# %%
type_dict = {
    "C":"Cold",
    "H":'Hot'
}

df['Type'] = df['Type'].map(type_dict)

# %% [markdown]
# Lets go!!

# %%
df.head(2)
# Out:
#                 Name Manufacturer  Type  Calories  Protein  Fat(g)  Sodium  \
# 0          100% Bran      Nabisco  Cold        70        4       1     130
# 1  100% Natural Bran  Quaker Oats  Cold       120        3       5      15
#
#    Fiber  Carbo  Sugars  Pottasium(mg)  Vitamins  Shelf  Weight  Cups  \
# 0   10.0    5.0       6            280        25      3     1.0  0.33
# 1    2.0    8.0       8            135         0      3     1.0  1.00
#
#       Rating
# 0  68.402973
# 1  33.983679

# %% [markdown]
# ### EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           77 non-null     object
#  1   Manufacturer   77 non-null     object
#  2   Type           77 non-null     object
#  3   Calories       77 non-null     int64
#  4   Protein        77 non-null     int64
#  5   Fat(g)         77 non-null     int64
#  6   Sodium         77 non-null     int64
#  7   Fiber          77 non-null     float64
#  8   Carbo          77 non-null     float64
#  9   Sugars         77 non-null     int64
#  10  Pottasium(mg)  77 non-null     int64
#  11  Vitamins       77 non-null     int64
#  12  Shelf          77 non-null     int64
#  13  Weight         77 non-null     float64
#  14  Cups           77 non-null     float64
#  15  Rating         77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
df.describe()
# Out:
#          Calories    Protein     Fat(g)      Sodium      Fiber      Carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           Sugars  Pottasium(mg)    Vitamins      Shelf     Weight       Cups  \
# count  77.000000      77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078      96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885      71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000      -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000      40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000      90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000     120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000     330.000000  100.000000   3.000000   1.500000   1.500000
#
#           Rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
g = df[df["Pottasium(mg)"] < 0]['Pottasium(mg)'].count()
h = df[df["Sugars"] < 0]['Sugars'].count()
i = df[df["Carbo"] < 0]['Carbo'].count()

print('negative values in Pottasium(mg) column:', g)
print('negative values in Sugars column:', h)
print('negative values in Carbo column:', i)
# Out:
# negative values in Pottasium(mg) column: 2
# negative values in Sugars column: 1
# negative values in Carbo column: 1

# %%
## replacing negative values in the dataset with the mean of the column. 
cols = df[['Carbo', 'Sugars', 'Pottasium(mg)']].mean()
df.replace(-1, cols, inplace=True)

# %%
df.isnull().sum()
# Out:
# Name             0
# Manufacturer     0
# Type             0
# Calories         0
# Protein          0
# Fat(g)           0
# Sodium           0
# Fiber            0
# Carbo            0
# Sugars           0
# Pottasium(mg)    0
# Vitamins         0
# Shelf            0
# Weight           0
# Cups             0
# Rating           0
# dtype: int64

# %%
df.describe()
# Out:
#          Calories    Protein     Fat(g)      Sodium      Fiber      Carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.799966
# std     19.484119   1.094790   1.006473   83.832295   2.383364   3.881605
# min     50.000000   1.000000   0.000000    0.000000   0.000000   5.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.597403
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           Sugars  Pottasium(mg)    Vitamins      Shelf     Weight       Cups  \
# count  77.000000      77.000000   77.000000  77.000000  77.000000  77.000000
# mean    7.024962      98.599427   28.246753   2.207792   1.029610   0.821039
# std     4.349770      69.479240   22.342523   0.832524   0.150477   0.232716
# min     0.000000      15.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000      45.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000      90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000     120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000     330.000000  100.000000   3.000000   1.500000   1.500000
#
#           Rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %%
unique_cereal_brands = df['Name'].unique()
print(f'There are {len(unique_cereal_brands)} unique brands in this dataset')
# Out:
# There are 77 unique brands in this dataset

# %%
unique_manufacturers = df['Manufacturer'].unique()
print(f'There are {len(unique_manufacturers)} unique manufacturers in this dataset')
# Out:
# There are 7 unique manufacturers in this dataset

# %%
### to see how many products owned by each manufacturer 
plt.figure(figsize=(6,4))
counts = df['Manufacturer'].value_counts()
sns.countplot(y='Manufacturer', data=df)
plt.ylabel('Name of the Manufacturers')
plt.xlabel('Number of products')
plt.title("Number of Products Per Manufacturer")
plt.show()

# %%
### to see the distribution of the rating of each manufacturer. plt.figure(figsize=(6,4))
plt.figure(figsize=(10,4))
sns.boxplot(x='Manufacturer', y='Rating', data=df)
plt.ylabel('Rating')
plt.xlabel('Name of Manufacturers')
plt.title("Distribution of Rating")
plt.xticks(rotation=90)
plt.show()

# %%
## Highest rated brand
df[df['Rating']==df['Rating'].max()][['Name', 'Rating', 'Manufacturer']]
# Out:
#                         Name     Rating Manufacturer
# 3  All-Bran with Extra Fiber  93.704912     Kelloggs

# %%
## Highest rated brand
df[df['Rating']==df['Rating'].min()][['Name', 'Rating', 'Manufacturer']]
# Out:
#             Name     Rating Manufacturer
# 10  Cap'n'Crunch  18.042851  Quaker Oats

# %% [markdown]
# Kellogs are the manufacturer of the Cereal with the highet rating, Quacker oats is the manufacturer with the lowest rated Cereal with a rating of 18.0

# %%
## which companies produce the highest
df[df['Calories']==df['Calories'].max()][['Name', 'Calories', 'Manufacturer', 'Rating']]
# Out:
#                     Name  Calories Manufacturer     Rating
# 46  Mueslix Crispy Blend       160     Kelloggs  30.313351

# %% [markdown]
# "Mueslix Crsipy Blend" is the cereal with the highest Calory per serving, and
# "All-Bran with Extra fiber", "Puffed Rice" and "Puffed wheat" are the cereals with the lowest rating.

# %%
df.boxplot('Rating', 'Type')
# Out:
# <Axes: title={'center': 'Rating'}, xlabel='Type'>

# %%
## to get the Cereals with the least amount of calories
lower_calories = df.sort_values(by='Calories', ascending=True)
lower_calories = lower_calories.head(10) 

## to get the cereals with the highest amount of calories
higher_caloric = df.sort_values(by='Calories', ascending=False)
higher_caloric = higher_caloric.head(10)

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.barh(higher_caloric['Name'],higher_caloric['Calories'], color = 'red', label = 'Top 10 caloric cereals')
ax.barh(lower_calories['Name'], lower_calories['Calories'], color = 'green', label = 'Bottom 10 caloric cereals')
ax.set_xlabel('Calories')
ax.set_ylabel('Cereal')
ax.set_title('Comparison between the 10 most and the 10 less caloric cereals')
ax.legend()

plt.show()

# %%
higher_caloric[['Name', 'Manufacturer', 'Rating']]
# Out:
#                                  Name    Manufacturer     Rating
# 46               Mueslix Crispy Blend        Kelloggs  30.313351
# 44   Muesli Raisins; Dates; & Almonds  Ralston Purina  37.136863
# 45  Muesli Raisins; Peaches; & Pecans  Ralston Purina  34.139765
# 70                  Total Raisin Bran   General Mills  28.592785
# 39             Just Right Fruit & Nut        Kelloggs  36.471512
# 49          Nutri-Grain Almond-Raisin        Kelloggs  40.692320
# 51               Oatmeal Raisin Crisp   General Mills  30.450843
# 7                             Basic 4   General Mills  37.038562
# 52              Post Nat. Raisin Bran            Post  37.840594
# 35                   Honey Graham Ohs     Quaker Oats  21.871292

# %%
sns.regplot(data=df, x='Calories', y='Rating')
# Out:
# <Axes: xlabel='Calories', ylabel='Rating'>

# %%
plt.figure(figsize=(10,4))
sns.boxplot(x='Manufacturer', y='Calories', data=df)
plt.ylabel('Calories')
plt.xlabel('Name of Manufacturers')
plt.title("Distribution of Calories")
plt.xticks(rotation=90)
plt.show()

# %%
## ploting the highest caloric cereals and thier manufacturers. 
sns.barplot(data=higher_caloric, x='Calories', y='Name', hue='Manufacturer')
# Out:
# <Axes: xlabel='Calories', ylabel='Name'>

# %%
## ploting the highest caloric cereals and thier manufacturers. 
sns.barplot(data=lower_calories, x='Calories', y='Name', hue='Manufacturer')
# Out:
# <Axes: xlabel='Calories', ylabel='Name'>

# %%
## checking for relationship between sugar content and thier ratings 

sns.regplot(data=df, x='Sugars', y='Rating')
# Out:
# <Axes: xlabel='Sugars', ylabel='Rating'>
